# %% [markdown]
# # Titanic : Machine Learning from Disaster

# %% [markdown]
# ## 1 - Importing Libraries
# * **Keras from Tensorflow** - for Deep Learning
# * **Pandas** - for Data Manipulation
# * **Numpy** - for Special Features
# * **Matplotlib** - for Data Visualization
# * **Random** - for Data Correction

# %%
# Import the libraries
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random as rd

print("Librairies successfully imported")

# Clearing the session
keras.backend.clear_session()

# Checking the versions
print(" - Tensorflow version: ", tf.__version__)
print(" - Keras version: ", keras.__version__)
print(" - Pandas version: ", pd.__version__)
print(" - Numpy version: ", np.__version__)
print(" - Matplotlib version: ", plt.matplotlib.__version__)
print(" - Random version: ", "NaN")
# Out:
# Librairies successfully imported
#  - Tensorflow version:  2.9.0
#  - Keras version:  2.9.0
#  - Pandas version:  2.0.0
#  - Numpy version:  1.23.5
#  - Matplotlib version:  3.7.1
#  - Random version:  NaN

# %% [markdown]
# ## 2 - Load data

# %%
data_folder_path = "data_titanic/"

# Loading the data
raw_train_data = pd.read_csv(data_folder_path + "train.csv")
raw_test_data = pd.read_csv(data_folder_path + "test.csv")

print("Data successfully loaded")
# Out:
# Data successfully loaded

# %% [markdown]
# ## 3 - Data Preprocessing

# %% [markdown]
# ### 3.1 - Data Visualization

# %%
# Displaying the first 5 rows of the training data
raw_train_data.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 3.2 - Looking for missing values

# %%
# Pandas filter for missing values
missing_value_filter_train_data = raw_train_data.isna().sum()[raw_train_data.isna().sum() > 0]
missing_value_filter_test_data = raw_test_data.isna().sum()[raw_test_data.isna().sum() > 0]

training_data_size = len(raw_train_data)
test_data_size = len(raw_test_data)

# Displaying the missing values for the training data
print("Missing values for the training data:")
for column_name, missing_value_number in missing_value_filter_train_data.items():
    print(" - ", column_name, ": ", missing_value_number,' / ', training_data_size)

# Displaying the missing values for the test data
print("Missing values for the test data:")
for column_name, missing_value_number in missing_value_filter_test_data.items():
    print(" - ", column_name, ": ", missing_value_number,' / ', test_data_size)
# Out:
# Missing values for the training data:
#  -  Age :  177  /  891
#  -  Cabin :  687  /  891
#  -  Embarked :  2  /  891
# Missing values for the test data:
#  -  Age :  86  /  418
#  -  Fare :  1  /  418
#  -  Cabin :  327  /  418

# %% [markdown]
# ### 3.3 - Strategy to fix missing values

# %% [markdown]
# Let's go through the features one by one and see what we can do about the missing values :
# * **Cabin** : In both data sets most of the values are missing, so we can drop this feature.
# * **Embarked** : There are only 2 missing values in the training set, so, in order not to polute the data, we can drop these 2 rows.
# * **Fare** : There is only 1 missing value in the test set, so we can replace it with the mean value of the feature.
# * **Age** : Will be replaced with the mean value of the feature.

# %% [markdown]
# ### 3.4 - Fixing the data for Cabin, Embarked, Fare and Age

# %%
# Droping the Cabin feature
raw_train_data.drop(columns=['Cabin'], inplace=True)
raw_test_data.drop(columns=['Cabin'], inplace=True)

# Dropping the Age feature
mean_train = raw_train_data['Age'].mean()
mean_test = raw_test_data['Age'].mean()
filled_value = round((mean_train*(training_data_size-177) + mean_test*(test_data_size-86))/(training_data_size+test_data_size-263),1)
raw_train_data['Age'].fillna(filled_value, inplace=True)
raw_test_data['Age'].fillna(filled_value, inplace=True)
print("Age missing values filled by : ", filled_value)

# Droping the raws with missing Embarked values
raw_train_data.dropna(subset=['Embarked'], inplace=True)

# Filling the missing values for the Fare feature
mean_Fare_train = raw_train_data['Fare'].mean()
mean_Fare_test = raw_test_data['Fare'].mean()
filled_value = round((mean_Fare_train*(training_data_size-2) + mean_Fare_test*(test_data_size-1))/(training_data_size+test_data_size-3),1)
raw_test_data['Fare'].fillna(filled_value, inplace=True)
print("Fare missing values filled by : ", filled_value)
# Out:
# Age missing values filled by :  29.9
# Fare missing values filled by :  33.2

# %% [markdown]
# ### 3.6 - Checking the data

# %%
# Re-checking the missing values
number_of_missing_values_train = raw_train_data.isna().sum()[raw_train_data.isna().sum() > 0].sum()
number_of_missing_values_test = raw_test_data.isna().sum()[raw_test_data.isna().sum() > 0].sum()
print("Number of missing values for the training data: ", number_of_missing_values_train)
print("Number of missing values for the test data: ", number_of_missing_values_test)

# Renaming the data
clean_train_data = raw_train_data
clean_test_data = raw_test_data
print()
print("Data successfully cleaned")
# Out:
# Number of missing values for the training data:  0
# Number of missing values for the test data:  0
#
# Data successfully cleaned

# %% [markdown]
# ## 4 - Data Normalizing and usable datasets creation

# %% [markdown]
# ### 4.1 - Data tranformation to categorical values
# A few modification on the data will be made :
# * The PassengerId column will be dropped.
# * The name column will be dropped as it is not relevant for the model.
# * The Ticket column will be dropped too as it doen't semm to give any information.
# * The Embarked feature will be tranformed reagarding the chronological steps of the Titanic Journey : Southampton -> Cherbourg -> Queenstown. Thus, we will perform the following transformation :
#     * S -> 0
#     * C -> 1
#     * Q -> 2
# * The Sex feature will be transformed as followed :
#     * male -> 0
#     * female -> 1

# %%
# Droping the PassengerId, Name and Ticket features
clean_test_data.drop(columns=['Name', 'Ticket'], inplace=True)
clean_train_data.drop(columns=['PassengerId', 'Name', 'Ticket'], inplace=True)

# Replacing the Embarked feature by a numerical feature
clean_train_data['Embarked'].replace(['S', 'C', 'Q'], [0, 1, 2], inplace=True)
clean_test_data['Embarked'].replace(['S', 'C', 'Q'], [0, 1, 2], inplace=True)

# Replacing the gender feature by a numerical feature
clean_train_data['Sex'].replace(['male','female'], [0, 1], inplace=True)
clean_test_data['Sex'].replace(['male','female'], [0, 1], inplace=True)

# %% [markdown]
# ### 4.2 - Data Normalizing

# %%
# Normalizing the train data set
for label in clean_train_data.columns:
    if label != 'Survived':
        mean = clean_train_data[label].mean()
        std = clean_train_data[label].std()
        clean_train_data[label] = clean_train_data[label].apply(lambda x: (x-mean)/std)

# Normalizing the test data set
for label in clean_test_data.columns:
    if label != 'PassengerId':
        mean = clean_test_data[label].mean()
        std = clean_test_data[label].std()
        clean_test_data[label] = clean_test_data[label].apply(lambda x: (x-mean)/std)

# %% [markdown]
# ### 4.3 - Data Shuffling and Splitting

# %%
# Shuffling the data
data = clean_train_data.sample(frac=1)

# Spliting the data
validation_data = data.sample(frac=0.2)
train_data = data.drop(validation_data.index)

# Creation of the entries and exits of our neural network
X_train = train_data.drop(columns=['Survived'])
Y_train = train_data['Survived']

X_validation = validation_data.drop(columns=['Survived'])
Y_validation = validation_data['Survived']

X_test = clean_test_data



print("Data in ready to be used for the training of the neural network")
print("X_train shape: ", X_train.shape)
print("Y_train shape: ", Y_train.shape)
# Out:
# Data in ready to be used for the training of the neural network
# X_train shape:  (711, 7)
# Y_train shape:  (711,)

# %% [markdown]
# ## 5 - Model Creation

# %%
shape = X_train.shape[1] # = 7

# Creation of the model
model = keras.models.Sequential()
model.add(keras.layers.Input(shape))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
for i in range(10):
    model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(8, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

# Compilation of the model
model.compile(optimizer = 'adam',
              loss      = 'binary_crossentropy',
              metrics   = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                512
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dense_6 (Dense)             (None, 16)                272
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 16)                272
#
#  dense_9 (Dense)             (None, 16)                272
#
#  dense_10 (Dense)            (None, 16)                272
#
#  dense_11 (Dense)            (None, 16)                272
#
#  dense_12 (Dense)            (None, 16)                272
#
#  dense_13 (Dense)            (None, 16)                272
#
#  dense_14 (Dense)            (None, 16)                272
#
#  dense_15 (Dense)            (None, 32)                544
#
#  dense_16 (Dense)            (None, 32)                1056
#
#  dense_17 (Dense)            (None, 16)                528
#
#  dense_18 (Dense)            (None, 16)                272
#
#  dense_19 (Dense)            (None, 8)                 136
#
#  dense_20 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 17,489
# Trainable params: 17,489
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 6 - Model Training

# %% [markdown]
# *Note : to select the bet model, we will choose the one that has the best accuracy on the validation set.*

# %%
save_directory = "prediction_titanic/best_model_mean_age.h5"

# Creation of a callback to save the best model
callback = keras.callbacks.ModelCheckpoint(filepath=save_directory, save_best_only=True, verbose=1, monitor='val_accuracy')

# Training the model
history = model.fit(  X_train, Y_train,
                      batch_size      = 10,
                      epochs          = 100,
                      verbose         = 1,
                      callbacks       = [callback],
                      validation_data = (X_validation, Y_validation))
# Out:
# Epoch 1/100
# 51/72 [====================>.........] - ETA: 0s - loss: 0.6758 - accuracy: 0.6000
# Epoch 1: val_accuracy improved from -inf to 0.63483, saving model to prediction_titanic\best_model_mean_age.h5
# 72/72 [==============================] - 2s 9ms/step - loss: 0.6433 - accuracy: 0.6048 - val_loss: 0.5208 - val_accuracy: 0.6348
# Epoch 2/100
# 72/72 [==============================] - ETA: 0s - loss: 0.5229 - accuracy: 0.7384
# Epoch 2: val_accuracy improved from 0.63483 to 0.77528, saving model to prediction_titanic\best_model_mean_age.h5
# 72/72 [==============================] - 0s 4ms/step - loss: 0.5229 - accuracy: 0.7384 - val_loss: 0.4900 - val_accuracy: 0.7753
# Epoch 3/100
# 50/72 [===================>..........] - ETA: 0s - loss: 0.4854 - accuracy: 0.8080
# Epoch 3: val_accuracy improved from 0.77528 to 0.80337, saving model to prediction_titanic\best_model_mean_age.h5
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4862 - accuracy: 0.8073 - val_loss: 0.4723 - val_accuracy: 0.8034
# Epoch 4/100
# 51/72 [====================>.........] - ETA: 0s - loss: 0.4596 - accuracy: 0.8235
# Epoch 4: val_accuracy did not improve from 0.80337
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4684 - accuracy: 0.8172 - val_loss: 0.5018 - val_accuracy: 0.7865
# Epoch 5/100
# 65/72 [==========================>...] - ETA: 0s - loss: 0.4745 - accuracy: 0.8092
# Epoch 5: val_accuracy improved from 0.80337 to 0.81461, saving model to prediction_titanic\best_model_mean_age.h5
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4693 - accuracy: 0.8115 - val_loss: 0.4537 - val_accuracy: 0.8146
# Epoch 6/100
# 63/72 [=========================>....] - ETA: 0s - loss: 0.4514 - accuracy: 0.8159
# Epoch 6: val_accuracy did not improve from 0.81461
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4503 - accuracy: 0.8186 - val_loss: 0.4701 - val_accuracy: 0.8034
# Epoch 7/100
# 48/72 [===================>..........] - ETA: 0s - loss: 0.4299 - accuracy: 0.8229
# Epoch 7: val_accuracy did not improve from 0.81461
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4327 - accuracy: 0.8256 - val_loss: 0.4237 - val_accuracy: 0.8146
# Epoch 8/100
# 49/72 [===================>..........] - ETA: 0s - loss: 0.4095 - accuracy: 0.8449
# Epoch 8: val_accuracy improved from 0.81461 to 0.84270, saving model to prediction_titanic\best_model_mean_age.h5
# 72/72 [==============================] - 0s 4ms/step - loss: 0.4252 - accuracy: 0.8312 - val_loss: 0.4051 - val_accuracy: 0.8427
# Epoch 9/100
# 72/72 [==============================] - ETA: 0s - loss: 0.4149 - accuracy: 0.8270
# Epoch 9: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4149 - accuracy: 0.8270 - val_loss: 0.4309 - val_accuracy: 0.8202
# Epoch 10/100
# 49/72 [===================>..........] - ETA: 0s - loss: 0.4054 - accuracy: 0.8367
# Epoch 10: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.4114 - accuracy: 0.8326 - val_loss: 0.4099 - val_accuracy: 0.8427
# Epoch 11/100
# 71/72 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.8423
# Epoch 11: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3930 - accuracy: 0.8425 - val_loss: 0.4164 - val_accuracy: 0.8258
# Epoch 12/100
# 72/72 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8425
# Epoch 12: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3971 - accuracy: 0.8425 - val_loss: 0.4488 - val_accuracy: 0.7978
# Epoch 13/100
# 72/72 [==============================] - ETA: 0s - loss: 0.3984 - accuracy: 0.8383
# Epoch 13: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3984 - accuracy: 0.8383 - val_loss: 0.4085 - val_accuracy: 0.8258
# Epoch 14/100
# 49/72 [===================>..........] - ETA: 0s - loss: 0.3796 - accuracy: 0.8571
# Epoch 14: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3853 - accuracy: 0.8509 - val_loss: 0.4658 - val_accuracy: 0.8034
# Epoch 15/100
# 72/72 [==============================] - ETA: 0s - loss: 0.3888 - accuracy: 0.8383
# Epoch 15: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.
val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3125 - accuracy: 0.8622 - val_loss: 0.4478 - val_accuracy: 0.8258
# Epoch 78/100
# 50/72 [===================>..........] - ETA: 0s - loss: 0.3035 - accuracy: 0.8660
# Epoch 78: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3102 - accuracy: 0.8608 - val_loss: 0.4881 - val_accuracy: 0.8202
# Epoch 79/100
# 71/72 [============================>.] - ETA: 0s - loss: 0.2963 - accuracy: 0.8648
# Epoch 79: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2959 - accuracy: 0.8650 - val_loss: 0.4919 - val_accuracy: 0.8371
# Epoch 80/100
# 72/72 [==============================] - ETA: 0s - loss: 0.3015 - accuracy: 0.8664
# Epoch 80: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3015 - accuracy: 0.8664 - val_loss: 0.5256 - val_accuracy: 0.8371
# Epoch 81/100
# 49/72 [===================>..........] - ETA: 0s - loss: 0.2928 - accuracy: 0.8694
# Epoch 81: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2940 - accuracy: 0.8678 - val_loss: 0.5458 - val_accuracy: 0.8315
# Epoch 82/100
# 61/72 [========================>.....] - ETA: 0s - loss: 0.3109 - accuracy: 0.8607
# Epoch 82: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3123 - accuracy: 0.8594 - val_loss: 0.4972 - val_accuracy: 0.8371
# Epoch 83/100
# 70/72 [============================>.] - ETA: 0s - loss: 0.3108 - accuracy: 0.8629
# Epoch 83: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3093 - accuracy: 0.8636 - val_loss: 0.5589 - val_accuracy: 0.8202
# Epoch 84/100
# 70/72 [============================>.] - ETA: 0s - loss: 0.2955 - accuracy: 0.8671
# Epoch 84: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2962 - accuracy: 0.8650 - val_loss: 0.5480 - val_accuracy: 0.8258
# Epoch 85/100
# 49/72 [===================>..........] - ETA: 0s - loss: 0.2869 - accuracy: 0.8612
# Epoch 85: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2904 - accuracy: 0.8678 - val_loss: 0.6081 - val_accuracy: 0.8315
# Epoch 86/100
# 51/72 [====================>.........] - ETA: 0s - loss: 0.2831 - accuracy: 0.8627
# Epoch 86: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3026 - accuracy: 0.8622 - val_loss: 0.4890 - val_accuracy: 0.7697
# Epoch 87/100
# 48/72 [===================>..........] - ETA: 0s - loss: 0.2888 - accuracy: 0.8479
# Epoch 87: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3034 - accuracy: 0.8509 - val_loss: 0.5986 - val_accuracy: 0.8202
# Epoch 88/100
# 66/72 [==========================>...] - ETA: 0s - loss: 0.2934 - accuracy: 0.8682
# Epoch 88: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2913 - accuracy: 0.8692 - val_loss: 0.6206 - val_accuracy: 0.8258
# Epoch 89/100
# 51/72 [====================>.........] - ETA: 0s - loss: 0.2727 - accuracy: 0.8706
# Epoch 89: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2880 - accuracy: 0.8664 - val_loss: 0.5002 - val_accuracy: 0.8146
# Epoch 90/100
# 48/72 [===================>..........] - ETA: 0s - loss: 0.2953 - accuracy: 0.8646
# Epoch 90: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.2977 - accuracy: 0.8650 - val_loss: 0.6021 - val_accuracy: 0.8258
# Epoch 91/100
# 50/72 [===================>..........] - ETA: 0s - loss: 0.3114 - accuracy: 0.8640
# Epoch 91: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3097 - accuracy: 0.8650 - val_loss: 0.6557 - val_accuracy: 0.8034
# Epoch 92/100
# 71/72 [============================>.] - ETA: 0s - loss: 0.3784 - accuracy: 0.8225
# Epoch 92: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 4ms/step - loss: 0.3787 - accuracy: 0.8228 - val_loss: 0.4989 - val_accuracy: 0.8146
# Epoch 93/100
# 55/72 [=====================>........] - ETA: 0s - loss: 0.3406 - accuracy: 0.8309
# Epoch 93: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3236 - accuracy: 0.8439 - val_loss: 0.4708 - val_accuracy: 0.8202
# Epoch 94/100
# 59/72 [=======================>......] - ETA: 0s - loss: 0.3143 - accuracy: 0.8525
# Epoch 94: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3107 - accuracy: 0.8579 - val_loss: 0.5390 - val_accuracy: 0.8202
# Epoch 95/100
# 72/72 [==============================] - ETA: 0s - loss: 0.3193 - accuracy: 0.8481
# Epoch 95: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3193 - accuracy: 0.8481 - val_loss: 0.4766 - val_accuracy: 0.8146
# Epoch 96/100
# 50/72 [===================>..........] - ETA: 0s - loss: 0.3248 - accuracy: 0.8480
# Epoch 96: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3126 - accuracy: 0.8495 - val_loss: 0.5149 - val_accuracy: 0.7978
# Epoch 97/100
# 49/72 [===================>..........] - ETA: 0s - loss: 0.3156 - accuracy: 0.8571
# Epoch 97: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3253 - accuracy: 0.8425 - val_loss: 0.4558 - val_accuracy: 0.8146
# Epoch 98/100
# 72/72 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.8594
# Epoch 98: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3130 - accuracy: 0.8594 - val_loss: 0.4903 - val_accuracy: 0.8258
# Epoch 99/100
# 72/72 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8565
# Epoch 99: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3075 - accuracy: 0.8565 - val_loss: 0.4622 - val_accuracy: 0.8202
# Epoch 100/100
# 71/72 [============================>.] - ETA: 0s - loss: 0.3585 - accuracy: 0.8366
# Epoch 100: val_accuracy did not improve from 0.84270
# 72/72 [==============================] - 0s 3ms/step - loss: 0.3582 - accuracy: 0.8368 - val_loss: 0.4677 - val_accuracy: 0.8146

# %% [markdown]
# ## 7 - Model Evaluation

# %% [markdown]
# Let's see how our model is performing during the training.

# %%
# Getting the evolution of the loss and the accuracy
train_loss = history.history['loss']
val_loss   = history.history['val_loss']
train_acc  = np.array(history.history['accuracy'])*100
val_acc    = np.array(history.history['val_accuracy'])*100

# Plotting the evolution of the loss and accuracy
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(train_loss, label='loss on the training data')
ax1.plot(val_loss, label='loss on the validation data')
ax1.set_title('Evolution of the loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss [binary cross entropy]')

ax2.plot(train_acc, label='accuracy on the training data')
ax2.plot(val_acc, label='accuracy on the validation data')
ax2.set_title('Evolution of the accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy [%]')

plt.legend()
plt.show()

# %% [markdown]
# How perfomant is the best model we can get ?

# %%
# Loading the best model
best_model = keras.models.load_model(save_directory)

# Best model evaluation
acc_val = round(best_model.evaluate(X_validation, Y_validation)[1]*100,1)
acc_train = round(best_model.evaluate(X_train, Y_train)[1]*100, 1)
print("Best model accuracy on the validation data: ", acc_val,'%')
print("Best model accuracy on the training data: ", acc_train,'%')
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.8427
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.8298
# Best model accuracy on the validation data:  84.3 %
# Best model accuracy on the training data:  83.0 %

# %% [markdown]
# ## 8 - Prediction

# %%
# Prediction of the test data
survival_prediction = best_model.predict(X_test.drop(columns=['PassengerId'])).flatten()
prediction = pd.DataFrame({'PassengerId': X_test['PassengerId'], 'Survived': [round(x) for x in survival_prediction]})

# Show somme of the first predictions
prediction.head()

# Saving the prediction
prediction.to_csv('prediction_titanic/prediction_mean_age.csv', index=False)
# Out:
# 14/14 [==============================] - 0s 1ms/step
