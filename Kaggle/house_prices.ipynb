# %% [markdown]
# # House Prices Prediction

# %% [markdown]
# ## Import the libraries

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import keras.backend as K


tf.keras.backend.clear_session()



print("Modules correctly imported")
# Out:
# Modules correctly imported

# %% [markdown]
# ## Load the datasets

# %%
train_file_path = "data_house_prices/train.csv"
test_file_path = "data_house_prices/test.csv"

dataset_train0 = pd.read_csv(train_file_path, header=0,sep=',')
dataset_test = pd.read_csv(test_file_path,header=0,sep=',')

display(dataset_train0.head(5))

dataset_train = dataset_train0.sample(frac=0.8,axis=0)
dataset_val = dataset_train0.drop(dataset_train.index)

X_train = dataset_train.drop(['Id','SalePrice'],axis=1)
Y_train = dataset_train['SalePrice']
X_val = dataset_val.drop(['Id','SalePrice'],axis=1)
Y_val = dataset_val['SalePrice']

X_test = dataset_test.drop(['Id'],axis=1)

print("Train set shape: ",X_train.shape)
print("Validation set shape: ",X_val.shape)
print("Test set shape: ",X_test.shape)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2  \
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]
# Train set shape:  (1168, 79)
# Validation set shape:  (292, 79)
# Test set shape:  (1459, 79)

# %% [markdown]
# ## Data exploration and missing values visualisation

# %%
print('\n Labels with NaN values in X_train, X_val and X_test')
print(X_train.isna().sum()[X_train.isna().sum()>0].index)
print(X_val.isna().sum()[X_val.isna().sum()>0].index)
print(X_test.isna().sum()[X_test.isna().sum()>0].index)

# Let's deal with NaN values that are allowed by the data description
Labels_with_NaN_values_allowed = ['Alley','MasVnrType','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PoolQC','Fence','MiscFeature']
for label in Labels_with_NaN_values_allowed:
    X_train[label].fillna('None',inplace=True)
    X_val[label].fillna('None',inplace=True)
    X_test[label].fillna('None',inplace=True)
    
print('\n After correction where NaN values are allowed')
print(X_train.isna().sum()[X_train.isna().sum()>0].index)
print(X_val.isna().sum()[X_val.isna().sum()>0].index)
print(X_test.isna().sum()[X_test.isna().sum()>0].index)

# Let's deal with NaN values that are replcaing numerical values
Labels_with_numerical_NaN_values = ['LotFrontage','MasVnrArea','GarageYrBlt','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','BsmtFullBath','BsmtHalfBath','GarageCars','GarageArea']
for label in Labels_with_numerical_NaN_values:
    mean = X_train[label].mean()
    X_train[label].fillna(mean,inplace=True)
    X_val[label].fillna(mean,inplace=True)
    X_test[label].fillna(mean,inplace=True)

print('\n After correction where numerical NaN values are replaced by mean')
print(X_train.isna().sum()[X_train.isna().sum()>0].index)
print(X_val.isna().sum()[X_val.isna().sum()>0].index)
print(X_test.isna().sum()[X_test.isna().sum()>0].index)
# Out:
#  Labels with NaN values in X_train, X_val and X_test
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature'],
#       dtype='object')
# Index(['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
#        'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType'],
#       dtype='object')
#
#  After correction where NaN values are allowed
# Index(['LotFrontage', 'MasVnrArea', 'Electrical', 'GarageYrBlt'], dtype='object')
# Index(['LotFrontage', 'MasVnrArea', 'GarageYrBlt'], dtype='object')
# Index(['MSZoning', 'LotFrontage', 'Utilities', 'Exterior1st', 'Exterior2nd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'SaleType'],
#       dtype='object')
#
#  After correction where numerical NaN values are replaced by mean
# Index(['Electrical'], dtype='object')
# Index([], dtype='object')
# Index(['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'KitchenQual',
#        'Functional', 'SaleType'],
#       dtype='object')

# %% [markdown]
# ## Finalisation of the datasets

# %%
electrical_most_frequent = X_train['Electrical'].mode()[0]
MSZoning_most_frequent = X_train['MSZoning'].mode()[0]
Utilities_most_frequent = X_train['Utilities'].mode()[0]
Exterior1st_most_frequent = X_train['Exterior1st'].mode()[0]
Exterior2nd_most_frequent = X_train['Exterior2nd'].mode()[0]
KitchenQual_most_frequent = X_train['KitchenQual'].mode()[0]
Functional_most_frequent = X_train['Functional'].mode()[0]
SaleType_most_frequent = X_train['SaleType'].mode()[0]

X_train['Electrical'].fillna(electrical_most_frequent,inplace=True)
X_test['MSZoning'].fillna(MSZoning_most_frequent,inplace=True)
X_test['Utilities'].fillna(Utilities_most_frequent,inplace=True)
X_test['Exterior1st'].fillna(Exterior1st_most_frequent,inplace=True)
X_test['Exterior2nd'].fillna(Exterior2nd_most_frequent,inplace=True)
X_test['KitchenQual'].fillna(KitchenQual_most_frequent,inplace=True)
X_test['Functional'].fillna(Functional_most_frequent,inplace=True)
X_test['SaleType'].fillna(SaleType_most_frequent,inplace=True)

print('\n After complete correction')
print(X_train.isna().sum()[X_train.isna().sum()>0].index)
print(X_val.isna().sum()[X_val.isna().sum()>0].index)
print(X_test.isna().sum()[X_test.isna().sum()>0].index)
# Out:
#  After complete correction
# Index([], dtype='object')
# Index([], dtype='object')
# Index([], dtype='object')

# %% [markdown]
# ## Transforming classification data into numerical data and normalization

# %%
Labels_with_classification_values = ['MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition']

for label in Labels_with_classification_values:
    X_train[label], mapping = pd.factorize(dataset_train[label], sort=True)
    X_val[label] = pd.Categorical(dataset_val[label], categories=mapping).codes
    X_test[label] = pd.Categorical(dataset_test[label], categories=mapping).codes

# Normalization
for label in X_train.columns:
    mean = X_train[label].mean()
    std = X_train[label].std()
    X_train[label] = (X_train[label]-mean)/std
    X_val[label] = (X_val[label]-mean)/std
    X_test[label] = (X_test[label]-mean)/std


# Search for NaN valmues
print('\n After normalization')
print(X_train.isna().sum()[X_train.isna().sum()>0].index)
print(X_val.isna().sum()[X_val.isna().sum()>0].index)
print(X_test.isna().sum()[X_test.isna().sum()>0].index)
# Out:
#  After normalization
# Index([], dtype='object')
# Index([], dtype='object')
# Index([], dtype='object')

# %% [markdown]
# ## Creating the model

# %%
entry_size = X_train.shape[1]
exit_size = 1
print("Entry size: ", entry_size)
print("Exit size: ", exit_size)

model = keras.models.Sequential()
model.add(keras.layers.Input(entry_size, name="InputLayer"))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1024, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1024, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dropout(0.3))

model.add(keras.layers.Dense(1, name='Output'))

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

model.compile(optimizer = 'adam',
            loss      = 'mae',
            metrics   = ['mae', 'mse'] )

model.summary()
# Out:
# Entry size:  79
# Exit size:  1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               10240
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1024)              263168
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 1024)              1049600
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 128)               131200
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  Output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 1,503,873
# Trainable params: 1,503,873
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
save_dir = "./prediction_house_prices/best_model.h5"

# Callbacks
savemodel_callback = tf.keras.callbacks.ModelCheckpoint(filepath=save_dir, verbose=1, save_best_only=True, monitor= 'val_loss', mode = 'min')


history = model.fit(X_train.astype(np.float32),
                    Y_train.astype(np.float32),
                    epochs          = 70,
                    batch_size      = 10,
                    verbose         = 1,
                    callbacks       = [savemodel_callback],
                    validation_data = (X_val.astype(np.float32), Y_val.astype(np.float32)))
# Out:
# Epoch 1/70
# 112/117 [===========================>..] - ETA: 0s - loss: 81349.5703 - mae: 81349.5703 - mse: 13787794432.0000
# Epoch 1: val_loss improved from inf to 29865.75781, saving model to ./prediction_house_prices\best_model.h5
# 117/117 [==============================] - 2s 12ms/step - loss: 79217.0859 - mae: 79217.0859 - mse: 13285990400.0000 - val_loss: 29865.7578 - val_mae: 29865.7578 - val_mse: 3495982336.0000
# Epoch 2/70
# 113/117 [===========================>..] - ETA: 0s - loss: 34242.6992 - mae: 34242.6992 - mse: 2291141632.0000
# Epoch 2: val_loss improved from 29865.75781 to 27259.84961, saving model to ./prediction_house_prices\best_model.h5
# 117/117 [==============================] - 1s 10ms/step - loss: 34265.4961 - mae: 34265.4961 - mse: 2302363392.0000 - val_loss: 27259.8496 - val_mae: 27259.8496 - val_mse: 3171367936.0000
# Epoch 3/70
# 116/117 [============================>.] - ETA: 0s - loss: 30558.8008 - mae: 30558.8008 - mse: 1898116736.0000
# Epoch 3: val_loss improved from 27259.84961 to 24565.46484, saving model to ./prediction_house_prices\best_model.h5
# 117/117 [==============================] - 1s 10ms/step - loss: 30577.1738 - mae: 30577.1738 - mse: 1895496320.0000 - val_loss: 24565.4648 - val_mae: 24565.4668 - val_mse: 3196646656.0000
# Epoch 4/70
# 117/117 [==============================] - ETA: 0s - loss: 30232.4492 - mae: 30232.4492 - mse: 2121865344.0000
# Epoch 4: val_loss did not improve from 24565.46484
# 117/117 [==============================] - 1s 9ms/step - loss: 30232.4492 - mae: 30232.4492 - mse: 2121865344.0000 - val_loss: 25629.9746 - val_mae: 25629.9746 - val_mse: 4139690496.0000
# Epoch 5/70
# 117/117 [==============================] - ETA: 0s - loss: 29656.3086 - mae: 29656.3086 - mse: 1705994624.0000
# Epoch 5: val_loss did not improve from 24565.46484
# 117/117 [==============================] - 1s 10ms/step - loss: 29656.3086 - mae: 29656.3086 - mse: 1705994624.0000 - val_loss: 31235.6777 - val_mae: 31235.6777 - val_mse: 4828589568.0000
# Epoch 6/70
# 111/117 [===========================>..] - ETA: 0s - loss: 32187.2793 - mae: 32187.2793 - mse: 2181953536.0000
# Epoch 6: val_loss did not improve from 24565.46484
# 117/117 [==============================] - 1s 9ms/step - loss: 32059.6777 - mae: 32059.6777 - mse: 2149943808.0000 - val_loss: 28789.9316 - val_mae: 28789.9316 - val_mse: 3280040704.0000
# Epoch 7/70
# 114/117 [============================>.] - ETA: 0s - loss: 28993.7598 - mae: 28993.7598 - mse: 1708885248.0000
# Epoch 7: val_loss did not improve from 24565.46484
# 117/117 [==============================] - 1s 9ms/step - loss: 29125.6309 - mae: 29125.6309 - mse: 1734535296.0000 - val_loss: 35545.2773 - val_mae: 35545.2773 - val_mse: 6444531200.0000
# Epoch 8/70
# 112/117 [===========================>..] - ETA: 0s - loss: 28506.4277 - mae: 28506.4277 - mse: 1810949632.0000
# Epoch 8: val_loss did not improve from 24565.46484
# 117/117 [==============================] - 1s 9ms/step - loss: 28510.0254 - mae: 28510.0254 - mse: 1788394240.0000 - val_loss: 28911.2637 - val_mae: 28911.2637 - val_mse: 4828197888.0000
# Epoch 9/70
# 115/117 [============================>.] - ETA: 0s - loss: 28610.7695 - mae: 28610.7695 - mse: 1779018240.0000
# Epoch 9: val_loss did not improve from 24565.46484
# 117/117 [==============================] - 1s 9ms/step - loss: 28574.2285 - mae: 28574.2285 - mse: 1768209280.0000 - val_loss: 29109.7676 - val_mae: 29109.7676 - val_mse: 4939094528.0000
# Epoch 10/70
# 114/117 [============================>.] - ETA: 0s - loss: 28484.8066 - mae: 28484.8047 - mse: 1561564416.0000
# Epoch 10: val_loss did not improve from 24565.46484
# 117/117 [==============================] - 1s 9ms/step - loss: 28433.0215 - mae: 28433.0195 - mse: 1551088128.0000 - val_loss: 27497.0156 - val_mae: 27497.0156 - val_mse: 5309306880.0000
# Epoch 11/70
# 116/117 [============================>.] - ETA: 0s - loss: 28473.4219 - mae: 28473.4219 - mse: 1696467712.0000
# Epoch 11: val_loss improved from 24565.46484 to 24371.98047, saving model to ./prediction_house_prices\best_model.h5
# 117/117 [==============================] - 1s 9ms/step - loss: 28410.3535 - mae: 28410.3535 - mse: 1689517440.0000 - val_loss: 24371.9805 - val_mae: 24371.9805 - val_mse: 3279298048.0000
# Epoch 12/70
# 113/117 [===========================>..] - ETA: 0s - loss: 28816.6445 - mae: 28816.6445 - mse: 1819480960.0000
# Epoch 12: val_loss improved from 24371.98047 to 23889.99219, saving model to ./prediction_house_prices\best_model.h5
# 117/117 [==============================] - 1s 10ms/step - loss: 28834.9922 - mae: 28834.9922 - mse: 1803491968.0000 - val_loss: 23889.9922 - val_mae: 23889.9922 - val_mse: 3762624768.0000
# Epoch 13/70
# 117/117 [==============================] - ETA: 0s - loss: 29023.3965 - mae: 29023.3965 - mse: 1765308928.0000
# Epoch 13: val_loss improved from 23889.99219 to 22875.68750, saving model to ./prediction_house_prices\best_model.h5
# 117/117 [==============================] - 1s 9ms/step - loss: 29023.3965 - mae: 29023.3965 - mse: 1765308928.0000 - val_loss: 22875.6875 - val_mae: 22875.6875 - val_mse: 3370394880.0000
# Epoch 14/70
# 112/117 [===========================>..] - ETA: 0s - loss: 27622.2363 - mae: 27622.2363 - mse: 1521900928.0000
# Epoch 14: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 28073.9238 - mae: 28073.9238 - mse: 1725080448.0000 - val_loss: 24259.8535 - val_mae: 24259.8535 - val_mse: 3900981504.0000
# Epoch 15/70
# 111/117 [===========================>..] - ETA: 0s - loss: 29637.4277 - mae: 29637.4277 - mse: 1832526592.0000
# Epoch 15: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 29650.8398 - mae: 29650.8398 - mse: 1824030720.0000 - val_loss: 28010.4043 - val_mae: 28010.4004 - val_mse: 4608385536.0000
# Epoch 16/70
# 114/117 [============================>.] - ETA: 0s - loss: 28317.2969 - mae: 28317.2969 - mse: 1818959104.0000
# Epoch 16: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 10ms/step - loss: 28204.1035 - mae: 28204.1035 - mse: 1799504256.0000 - val_loss: 23783.6328 - val_mae: 23783.6328 - val_mse: 3790036224.0000
# Epoch 17/70
# 117/117 [==============================] - ETA: 0s - loss: 28246.6504 - mae: 28246.6504 - mse: 1784796672.0000
# Epoch 17: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 28246.6504 - mae: 28246.6504 - mse: 1784796672.0000 - val_loss: 25688.7559 - val_mae: 25688.7559 - val_mse: 3803973376.0000
# Epoch 18/70
# 112/117 [===========================>..] - ETA: 0s - loss: 28454.1621 - mae: 28454.1621 - mse: 1730992896.0000
# Epoch 18: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 28423.7422 - mae: 28423.7422 - mse: 1714225408.0000 - val_loss: 24512.3164 - val_mae: 24512.3164 - val_mse: 4486938624.0000
# Epoch 19/70
# 116/117 [============================>.] - ETA: 0s - loss: 27187.5957 - mae: 27187.5957 - mse: 1402295936.0000
# Epoch 19: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27145.5273 - mae: 27145.5273 - mse: 1398629632.0000 - val_loss: 29205.6367 - val_mae: 29205.6367 - val_mse: 3771725568.0000
# Epoch 20/70
# 116/117 [============================>.] - ETA: 0s - loss: 27575.6406 - mae: 27575.6406 - mse: 1594217600.0000
# Epoch 20: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27552.4316 - mae: 27552.4316 - mse: 1588059008.0000 - val_loss: 25673.5469 - val_mae: 25673.5469 - val_mse: 4099752704.0000
# Epoch 21/70
# 115/117 [============================>.] - ETA: 0s - loss: 27767.5840 - mae: 27767.5840 - mse: 1553016192.0000
# Epoch 21: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27613.0586 - mae: 27613.0586 - mse: 1541852544.0000 - val_loss: 24532.3574 - val_mae: 24532.3574 - val_mse: 4183704576.0000
# Epoch 22/70
# 111/117 [===========================>..] - ETA: 0s - loss: 26526.4102 - mae: 26526.4102 - mse: 1428417408.0000
# Epoch 22: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26544.5137 - mae: 26544.5137 - mse: 1433050624.0000 - val_loss: 24276.7754 - val_mae: 24276.7754 - val_mse: 3859078400.0000
# Epoch 23/70
# 114/117 [============================>.] - ETA: 0s - loss: 27838.3340 - mae: 27838.3340 - mse: 1667792128.0000
# Epoch 23: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27693.5723 - mae: 27693.5723 - mse: 1647656576.0000 - val_loss: 27055.6406 - val_mae: 27055.6406 - val_mse: 5328824832.0000
# Epoch 24/70
# 116/117 [============================>.] - ETA: 0s - loss: 27792.3555 - mae: 27792.3555 - mse: 1735108608.0000
# Epoch 24: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27892.4629 - mae: 27892.4629 - mse: 1739375232.0000 - val_loss: 24506.2070 - val_mae: 24506.2070 - val_mse: 3701846784.0000
# Epoch 25/70
# 116/117 [============================>.] - ETA: 0s - loss: 27044.1191 - mae: 27044.1191 - mse: 1628552192.0000
# Epoch 25: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27159.4199 - mae: 27159.4199 - mse: 1644251392.0000 - val_loss: 25339.3535 - val_mae: 25339.3535 - val_mse: 3870618112.0000
# Epoch 26/70
# 114/117 [============================>.] - ETA: 0s - loss: 26371.2070 - mae: 26371.2070 - mse: 1523448064.0000
# Epoch 26: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26479.5898 - mae: 26479.5898 - mse: 1518605824.0000 - val_loss: 24077.7324 - val_mae: 24077.7324 - val_mse: 3883118848.0000
# Epoch 27/70
# 116/117 [============================>.] - ETA: 0s - loss: 27390.9336 - mae: 27390.9336 - mse: 1571054976.0000
# Epoch 27: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27474.3320 - mae: 27474.3320 - mse: 1573163776.0000 - val_loss: 23824.3125 - val_mae: 23824.3125 - val_mse: 3269360128.0000
# Epoch 28/70
# 117/117 [==============================] - ETA: 0s - loss: 25951.3926 - mae: 25951.3926 - mse: 1370690304.0000
# Epoch 28: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25951.3926 - mae: 25951.3926 - mse: 1370690304.0000 - val_loss: 24464.3926 - val_mae: 24464.3926 - val_mse: 4172129536.0000
# Epoch 29/70
# 111/117 [===========================>..] - ETA: 0s - loss: 28666.1445 - mae: 28666.1406 - mse: 1876808320.0000
# Epoch 29: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 28542.0898 - mae: 28542.0859 - mse: 1841183232.0000 - val_loss: 25238.1211 - val_mae: 25238.1211 - val_mse: 3656708864.0000
# Epoch 30/70
# 112/117 [===========================>..] - ETA: 0s - loss: 25778.2637 - mae: 25778.2637 - mse: 1257539584.0000
# Epoch 30: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25945.6211 - mae: 25945.6211 - mse: 1265213952.0000 - val_loss: 29830.0000 - val_mae: 29830.0000 - val_mse: 3429491968.0000
# Epoch 31/70
# 114/117 [============================>.] - ETA: 0s - loss: 27861.0137 - mae: 27861.0137 - mse: 1578377088.0000
# Epoch 31: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27873.9258 - mae: 27873.9258 - mse: 1570881024.0000 - val_loss: 25066.9062 - val_mae: 25066.9043 - val_mse: 4282599936.0000
# Epoch 32/70
# 111/117 [===========================>..] - ETA: 0s - loss: 27896.9590 - mae: 27896.9590 - mse: 1541400832.0000
# Epoch 32: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27652.0215 - mae: 27652.0215 - mse: 1503276544.0000 - val_loss: 23178.2559 - val_mae: 23178.2559 - val_mse: 3341047808.0000
# Epoch 33/70
# 111/117 [===========================>..] - ETA: 0s - loss: 24407.1602 - mae: 24407.1602 - mse: 1202753664.0000
# Epoch 33: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 24577.5176 - mae: 24577.5176 - mse: 1213188480.0000 - val_loss: 30569.2461 - val_mae: 30569.2461 - val_mse: 4996763648.0000
# Epoch 34/70
# 116/117 [============================>.] - ETA: 0s - loss: 27154.3652 - mae: 27154.3652 - mse: 1527789184.0000
# Epoch 34: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27160.4863 - mae: 27160.4863 - mse: 1524589440.0000 - val_loss: 25165.5762 - val_mae: 25165.5762 - val_mse: 4514415616.0000
# Epoch 35/70
# 117/117 [==============================] - ETA: 0s - loss: 26170.6230 - mae: 26170.6230 - mse: 1512272000.0000
# Epoch 35: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26170.6230 - mae: 26170.6230 - mse: 1512272000.0000 - val_loss: 26649.9941 - val_mae: 26649.9941 - val_mse: 4453993984.0000
# Epoch 36/70
# 115/117 [============================>.] - ETA: 0s - loss: 25757.8008 - mae: 25757.8008 - mse: 1509246208.0000
# Epoch 36: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25739.0820 - mae: 25739.0820 - mse: 1501920768.0000 - val_loss: 28019.5293 - val_mae: 28019.5293 - val_mse: 4688658944.0000
# Epoch 37/70
# 113/117 [===========================>..] - ETA: 0s - loss: 25859.9707 - mae: 25859.9707 - mse: 1317594112.0000
# Epoch 37: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25746.6328 - mae: 25746.6328 - mse: 1304193408.0000 - val_loss: 28682.4551 - val_mae: 28682.4551 - val_mse: 4628438528.0000
# Epoch 38/70
# 116/117 [============================>.] - ETA: 0s - loss: 26888.0078 - mae: 26888.0078 - mse: 1499382400.0000
# Epoch 38: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 10ms/step - loss: 26851.4785 - mae: 26851.4785 - mse: 1494514304.0000 - val_loss: 37228.0586 - val_mae: 37228.0586 - val_mse: 6108956160.0000
# Epoch 39/70
# 111/117 [===========================>..] - ETA: 0s - loss: 26527.7480 - mae: 26527.7480 - mse: 1505689344.0000
# Epoch 39: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26171.5625 - mae: 26171.5625 - mse: 1460023680.0000 - val_loss: 23160.7051 - val_mae: 23160.7051 - val_mse: 3579926784.0000
# Epoch 40/70
# 117/117 [==============================] - ETA: 0s - loss: 26981.1426 - mae: 26981.1445 - mse: 1519181056.0000
# Epoch 40: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26981.1426 - mae: 26981.1445 - mse: 1519181056.0000 - val_loss: 23975.3945 - val_mae: 23975.3945 - val_mse: 3683362816.0000
# Epoch 41/70
# 117/117 [==============================] - ETA: 0s - loss: 25825.2949 - mae: 25825.2949 - mse: 1327600896.0000
# Epoch 41: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25825.2949 - mae: 25825.2949 - mse: 1327600896.0000 - val_loss: 34984.6797 - val_mae: 34984.6797 - val_mse: 6596015616.0000
# Epoch 42/70
# 117/117 [==============================] - ETA: 0s - loss: 26038.8340 - mae: 26038.8340 - mse: 1467909120.0000
# Epoch 42: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26038.8340 - mae: 26038.8340 - mse: 1467909120.0000 - val_loss: 23374.1035 - val_mae: 23374.1035 - val_mse: 4084005120.0000
# Epoch 43/70
# 111/117 [===========================>..] - ETA: 0s - loss: 27055.7969 - mae: 27055.7969 - mse: 1385010944.0000
# Epoch 43: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27440.7168 - mae: 27440.7168 - mse: 1552369024.0000 - val_loss: 29502.4238 - val_mae: 29502.4238 - val_mse: 3471684352.0000
# Epoch 44/70
# 114/117 [============================>.] - ETA: 0s - loss: 25379.0293 - mae: 25379.0293 - mse: 1410271232.0000
# Epoch 44: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25580.8672 - mae: 25580.8672 - mse: 1441175808.0000 - val_loss: 27403.3496 - val_mae: 27403.3496 - val_mse: 4878086656.0000
# Epoch 45/70
# 111/117 [===========================>..] - ETA: 0s - loss: 25682.5449 - mae: 25682.5449 - mse: 1394853888.0000
# Epoch 45: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25625.5801 - mae: 25625.5801 - mse: 1381519616.0000 - val_loss: 25917.1621 - val_mae: 25917.1621 - val_mse: 3927738112.0000
# Epoch 46/70
# 115/117 [============================>.] - ETA: 0s - loss: 26660.4141 - mae: 26660.4141 - mse: 1533495040.0000
# Epoch 46: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26617.3008 - mae: 26617.3008 - mse: 1522915584.0000 - val_loss: 23103.9805 - val_mae: 23103.9805 - val_mse: 4459817984.0000
# Epoch 47/70
# 117/117 [==============================] - ETA: 0s - loss: 26115.4297 - mae: 26115.4297 - mse: 1395311360.0000
# Epoch 47: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26115.4297 - mae: 26115.4297 - mse: 1395311360.0000 - val_loss: 26668.4395 - val_mae: 26668.4395 - val_mse: 3331753472.0000
# Epoch 48/70
# 114/117 [============================>.] - ETA: 0s - loss: 25700.0371 - mae: 25700.0332 - mse: 1576003328.0000
# Epoch 48: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 10ms/step - loss: 25643.2559 - mae: 25643.2520 - mse: 1559822592.0000 - val_loss: 24342.1836 - val_mae: 24342.1836 - val_mse: 3884400896.0000
# Epoch 49/70
# 114/117 [============================>.] - ETA: 0s - loss: 26446.8535 - mae: 26446.8535 - mse: 1390308096.0000
# Epoch 49: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26386.5059 - mae: 26386.5059 - mse: 1380140672.0000 - val_loss: 23865.8398 - val_mae: 23865.8398 - val_mse: 4065143808.0000
# Epoch 50/70
# 117/117 [==============================] - ETA: 0s - loss: 25282.0645 - mae: 25282.0645 - mse: 1299845632.0000
# Epoch 50: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25282.0645 - mae: 25282.0645 - mse: 1299845632.0000 - val_loss: 31424.2773 - val_mae: 31424.2773 - val_mse: 5060273152.0000
# Epoch 51/70
# 111/117 [===========================>..] - ETA: 0s - loss: 27285.5664 - mae: 27285.5664 - mse: 1444078336.0000
# Epoch 51: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27596.2266 - mae: 27596.2266 - mse: 1598865792.0000 - val_loss: 31297.7598 - val_mae: 31297.7598 - val_mse: 3995156736.0000
# Epoch 52/70
# 112/117 [===========================>..] - ETA: 0s - loss: 27368.9668 - mae: 27368.9668 - mse: 1498212992.0000
# Epoch 52: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 27142.6953 - mae: 27142.6953 - mse: 1470904064.0000 - val_loss: 24519.6660 - val_mae: 24519.6660 - val_mse: 3726585344.0000
# Epoch 53/70
# 117/117 [==============================] - ETA: 0s - loss: 25964.1465 - mae: 25964.1465 - mse: 1529201664.0000
# Epoch 53: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25964.1465 - mae: 25964.1465 - mse: 1529201664.0000 - val_loss: 26357.8750 - val_mae: 26357.8750 - val_mse: 4127161856.0000
# Epoch 54/70
# 117/117 [==============================] - ETA: 0s - loss: 26151.0547 - mae: 26151.0547 - mse: 1440524160.0000
# Epoch 54: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26151.0547 - mae: 26151.0547 - mse: 1440524160.0000 - val_loss: 23794.2852 - val_mae: 23794.2852 - val_mse: 3902484736.0000
# Epoch 55/70
# 117/117 [==============================] - ETA: 0s - loss: 26159.9766 - mae: 26159.9766 - mse: 1477275520.0000
# Epoch 55: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26159.9766 - mae: 26159.9766 - mse: 1477275520.0000 - val_loss: 25529.5566 - val_mae: 25529.5566 - val_mse: 3151924992.0000
# Epoch 56/70
# 111/117 [===========================>..] - ETA: 0s - loss: 28095.4219 - mae: 28095.4219 - mse: 1761396480.0000
# Epoch 56: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 28178.9902 - mae: 28178.9902 - mse: 1763482240.0000 - val_loss: 22964.4277 - val_mae: 22964.4277 - val_mse: 3817195008.0000
# Epoch 57/70
# 115/117 [============================>.] - ETA: 0s - loss: 25586.7812 - mae: 25586.7812 - mse: 1505008768.0000
# Epoch 57: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25510.2285 - mae: 25510.2285 - mse: 1492856832.0000 - val_loss: 24213.8691 - val_mae: 24213.8691 - val_mse: 3798601216.0000
# Epoch 58/70
# 114/117 [============================>.] - ETA: 0s - loss: 26529.4414 - mae: 26529.4414 - mse: 1401201664.0000
# Epoch 58: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26562.7910 - mae: 26562.7910 - mse: 1396937984.0000 - val_loss: 22982.3496 - val_mae: 22982.3496 - val_mse: 3460928000.0000
# Epoch 59/70
# 116/117 [============================>.] - ETA: 0s - loss: 24051.9570 - mae: 24051.9570 - mse: 1183395712.0000
# Epoch 59: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 10ms/step - loss: 24020.8770 - mae: 24020.8770 - mse: 1178878208.0000 - val_loss: 24211.8066 - val_mae: 24211.8066 - val_mse: 4133227264.0000
# Epoch 60/70
# 116/117 [============================>.] - ETA: 0s - loss: 24773.1016 - mae: 24773.1016 - mse: 1363407872.0000
# Epoch 60: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 24755.7246 - mae: 24755.7246 - mse: 1359765632.0000 - val_loss: 25923.1035 - val_mae: 25923.1035 - val_mse: 3842039040.0000
# Epoch 61/70
# 116/117 [============================>.] - ETA: 0s - loss: 25503.8926 - mae: 25503.8926 - mse: 1414018048.0000
# Epoch 61: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25475.7949 - mae: 25475.7949 - mse: 1408630272.0000 - val_loss: 23086.5391 - val_mae: 23086.5391 - val_mse: 3898333184.0000
# Epoch 62/70
# 116/117 [============================>.] - ETA: 0s - loss: 25127.6895 - mae: 25127.6895 - mse: 1211173888.0000
# Epoch 62: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25217.0371 - mae: 25217.0371 - mse: 1217610624.0000 - val_loss: 23782.4844 - val_mae: 23782.4824 - val_mse: 3683857408.0000
# Epoch 63/70
# 116/117 [============================>.] - ETA: 0s - loss: 25668.7207 - mae: 25668.7207 - mse: 1316712448.0000
# Epoch 63: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25633.0312 - mae: 25633.0312 - mse: 1316418432.0000 - val_loss: 26373.2266 - val_mae: 26373.2266 - val_mse: 4944150528.0000
# Epoch 64/70
# 116/117 [============================>.] - ETA: 0s - loss: 25822.6230 - mae: 25822.6230 - mse: 1427578496.0000
# Epoch 64: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25752.8789 - mae: 25752.8789 - mse: 1419952768.0000 - val_loss: 23572.2363 - val_mae: 23572.2363 - val_mse: 3621155840.0000
# Epoch 65/70
# 117/117 [==============================] - ETA: 0s - loss: 26053.7285 - mae: 26053.7285 - mse: 1338767104.0000
# Epoch 65: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26053.7285 - mae: 26053.7285 - mse: 1338767104.0000 - val_loss: 24843.5879 - val_mae: 24843.5879 - val_mse: 4047219712.0000
# Epoch 66/70
# 116/117 [============================>.] - ETA: 0s - loss: 25948.2793 - mae: 25948.2793 - mse: 1477181696.0000
# Epoch 66: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 25914.4746 - mae: 25914.4746 - mse: 1473390848.0000 - val_loss: 31038.8359 - val_mae: 31038.8359 - val_mse: 5243438080.0000
# Epoch 67/70
# 117/117 [==============================] - ETA: 0s - loss: 24630.2070 - mae: 24630.2070 - mse: 1184122112.0000
# Epoch 67: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 24630.2070 - mae: 24630.2070 - mse: 1184122112.0000 - val_loss: 23607.7676 - val_mae: 23607.7676 - val_mse: 3807391488.0000
# Epoch 68/70
# 112/117 [===========================>..] - ETA: 0s - loss: 26300.0215 - mae: 26300.0215 - mse: 1517432576.0000
# Epoch 68: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26336.3770 - mae: 26336.3770 - mse: 1503548800.0000 - val_loss: 31313.7715 - val_mae: 31313.7715 - val_mse: 3624448000.0000
# Epoch 69/70
# 113/117 [===========================>..] - ETA: 0s - loss: 26665.6777 - mae: 26665.6777 - mse: 1435634688.0000
# Epoch 69: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 9ms/step - loss: 26578.0938 - mae: 26578.0938 - mse: 1415491456.0000 - val_loss: 30383.1543 - val_mae: 30383.1543 - val_mse: 5597127680.0000
# Epoch 70/70
# 115/117 [============================>.] - ETA: 0s - loss: 26647.6211 - mae: 26647.6211 - mse: 1503940224.0000
# Epoch 70: val_loss did not improve from 22875.68750
# 117/117 [==============================] - 1s 10ms/step - loss: 26657.7383 - mae: 26657.7383 - mse: 1504767872.0000 - val_loss: 23487.5684 - val_mae: 23487.5684 - val_mse: 3109171712.0000

# %% [markdown]
# ## Evaluation of our model

# %%
train_mae = history.history['mae']
val_mae   = history.history['val_mae']

epochs = range(1, len(train_mae) + 1)

plt.plot(epochs, train_mae, 'b', label='Training mae')
plt.plot(epochs, val_mae, 'r', label='Validation mae')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Percentage error

# %%
mean_price_train = Y_train.mean()
mean_price_val = Y_val.mean()
Percent_error_train = train_mae/mean_price_train*100
Percent_error_val = val_mae/mean_price_val*100

plt.plot(epochs, Percent_error_train, 'b', label='Training error')
plt.plot(epochs, Percent_error_val, 'r', label='Validation error')
plt.title('Training and validation error')
plt.xlabel('Epochs')
plt.ylabel('Error [%]')
plt.legend()

plt.show()

print("Best porcentage error in validation: ", min(Percent_error_val))
# Out:
# Best porcentage error in validation:  12.6319784122677

# %% [markdown]
# ## Predictions

# %%
# Load the best model
best_model = keras.models.load_model(save_dir)


predicted_price = best_model.predict(X_test.astype(np.float32))
solution = pd.DataFrame({'Id': dataset_test.Id, 'SalePrice': predicted_price.flatten()})
solution.to_csv('prediction_house_prices/price_predictions.csv', index=False)
# Out:
# 46/46 [==============================] - 0s 3ms/step
